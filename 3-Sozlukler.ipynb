# %%
benim_listem=[1,2,3,4]
benim_listem[0]
# Out:
# 1

# %% [markdown]
# Dictionary,Sözlük. key-value pairing(anahtar kelime-değer eşleşmesi)

# %%
benim_yemeklerim =["elma","armut","karpuz"]

# %%
benim_kalorilerim=[100,200,300]

# %%
benim_yemeklerim[1]
# Out:
# 'armut'

# %%
benim_kalorilerim=[100,200,300]

# %%
benim_kalorilerim[1]
# Out:
# 200

# %%
benim_sozluk = {"anahtarkelime":"değer"}

# %%
benim_sozluk ["anahtarkelime"]
# Out:
# 'değer'

# %%
benim_kalori_yemek_sozlugum = {"elma":100,"armut":200,"karpuz":300}

# %%
benim_kalori_yemek_sozlugum["elma"]
# Out:
# 100

# %%
type(benim_kalori_yemek_sozlugum)
# Out:
# dict

# %%
benim_kalori_yemek_sozlugum.items() #elemanları liste içerisinde veriyor
# Out:
# dict_items([('elma', 100), ('armut', 200), ('karpuz', 300)])

# %%
benim_kalori_yemek_sozlugum.values() #values sadece değerleri veriyor "keys" ise anahtarları veriyor
# Out:
# dict_values([100, 200, 300])

# %%
benim_kalori_yemek_sozlugum["uzum"]=400

# %%
benim_kalori_yemek_sozlugum
# Out:
# {'elma': 100, 'armut': 200, 'karpuz': 300, 'uzum': 400}

# %%
benim_kalori_yemek_sozlugum["elma"]=150

# %%
benim_kalori_yemek_sozlugum
# Out:
# {'elma': 150, 'armut': 200, 'karpuz': 300, 'uzum': 400}

# %%
garip_sozluk={1:"atıl",2:"zeynep"}

# %%
garip_sozluk[1]
# Out:
# 'atıl'

# %%
karisik_sozluk={"anahtar":100,20:"değer"}

# %%
karisik_sozluk["anahtar"]
# Out:
# 100

# %%
listeli_sozluk={"anahtar1":100,"anahtar2":[1,2,3,4,5],"anahtar3":{"anahtar25":25400}}

# %%
listeli_sozluk["anahtar1"]
# Out:
# 100

# %%
listeli_sozluk["anahtar2"]
# Out:
# [1, 2, 3, 4, 5]

# %%
listeli_sozluk["anahtar3"]
# Out:
# {'anahtar25': 25400}

# %%
listeli_sozluk["anahtar3"]["anahtar25"]
# Out:
# 25400

# %%
#Set

# %%
liste_ornegi =[1,2,3,4,1,2,3]

# %%
liste_ornegi
# Out:
# [1, 2, 3, 4, 1, 2, 3]

# %%
type(liste_ornegi)
# Out:
# list

# %%
set_hali = set(liste_ornegi)   #birden fazla tekrarlayanı siliyor

# %%
set_hali
# Out:
# {1, 2, 3, 4}

# %%
benim_setim = {"a","b","c","a"}

# %%
benim_setim
# Out:
# {'a', 'b', 'c'}

# %%
ornek_liste=[1,2,3,4,1,2,3,4]

# %%
tekil_set = set(ornek_liste)

# %%
tekil_liste = list(tekil_set)

# %%
tekil_liste
# Out:
# [1, 2, 3, 4]

# %%
bos_liste=[]

# %%
type(bos_liste)
# Out:
# list

# %%
bos_liste.append(10)
bos_liste.append(20)

# %%
bos_liste
# Out:
# [10, 20]

# %%
bos_sozluk={}

# %%
type(bos_sozluk)
# Out:
# dict

# %%
bos_sozluk["a"]=100

# %%
bos_sozluk
# Out:
# {'a': 100}

# %%
bos_set=set()

# %%
type(bos_set)
# Out:
# set

# %%
bos_set
# Out:
# set()

# %%
bos_set.add(10)
bos_set.add(10)
bos_set.add(10)
bos_set.add(20)

# %%
bos_set
# Out:
# {10, 20}

# %%
diger_liste=list()

# %%
type(diger_liste)
# Out:
# list

# %%
diger_liste
# Out:
# []

# %%
diger_liste.append(10)

# %%
diger_liste
# Out:
# [10]

# %%
diger_sozluk =dict()

# %%
type(diger_sozluk)
# Out:
# dict

# %%
diger_sozluk["anahtar"]= "değer"

# %%
diger_sozluk
# Out:
# {'anahtar': 'değer'}

# %%
#tuple

# %%
normal_liste =[1,2,"c",4.5]

# %%
normal_liste [0]
# Out:
# 1

# %%
normal_liste.append(6)

# %%
normal_liste[0] =100

# %%
normal_liste
# Out:
# [100, 2, 'c', 4.5, 6]

# %%
benim_tuple = (1,2,"c",4.5)

# %%
type(benim_tuple)
# Out:
# tuple

# %%
benim_tuple[0]  #tuple da elemanı değiştiremiyoruz.
# Out:
# 1

# %%
benim_tuple
# Out:
# (1, 2, 'c', 4.5)

# %%
benim_listem =list(benim_tuple)

# %%
benim_listem
# Out:
# [1, 2, 'c', 4.5]

# %%
benim_listem[0]=100

# %%
benim_listem
# Out:
# [100, 2, 'c', 4.5]
