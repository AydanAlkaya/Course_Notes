# %%
def toplama(num1,num2):
    return num1 + num2

# %%
a = int(input("ilk numarayı giriniz: "))
b = int(input("ikinci numarayı giriniz: "))
toplama(a,b)
# Out:
# ilk numarayı giriniz: 1
# ikinci numarayı giriniz: 2
# 3

# %%
#hataları ele almak -error handling

# %%
# try & except & else & finally

# %%
try:
    a = int(input("ilk numarayı giriniz: "))
    b = int(input("ikinci numarayı giriniz: "))
    print(toplama(a,b))
except:
    print("lütfen doğru bir numara giriniz")
# Out:
# ilk numarayı giriniz: 1
# ikinci numarayı giriniz: 2
# 3

# %%
try:
    yeni_int = int(input("numaranızı giriniz: "))
except:
    print("sanırsam yanlış numara girdiniz")
else:
    print("teşekkürler")
finally:
    print("finally çağırıldı")
# Out:
# numaranızı giriniz: 1
# teşekkürler
# finally çağırıldı

# %%
while True:
    try:
        yeni_int = int(input("numaranızı giriniz: "))
    except:
        print("sanırsam yanlış numara girdiniz")
        continue
    else:
        print("teşekkürler")
        break
    finally:
        print("finally çağırıldı")
# Out:
# numaranızı giriniz: 2
# teşekkürler
# finally çağırıldı

# %%
def hesapla(x,y,islem):
    if islem not in "+-*/":
        return "Lütfen işlemleri düzgün seçiniz: + - * /"
    
    if islem == "+":
        return x+y
    
    elif islem == "-":
        return x-y

    elif islem == "*":
        return x*y
    
    elif islem == "/":
        return x/y
    
    
while True:
    try:
        ilk_numara = int(input("ilk numarayı giriniz: "))
        ikinci_numara = int(input("ikinci numarayı giriniz: "))
        islem = input("işleminizi seçiniz : + - * /")
        print(hesapla(ilk_numara,ikinci_numara,islem))
    except:
        print("lütfen sayıları düzgün giriniz")
    else:
        print("sonra görüşmek üzere")
        break
# Out:
# ilk numarayı giriniz: 5
# ikinci numarayı giriniz: 4
# işleminizi seçiniz : + - * /+
# 9
# sonra görüşmek üzere
